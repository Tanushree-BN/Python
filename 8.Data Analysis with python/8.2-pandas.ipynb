# %% [markdown]
# Pandas-DataFrame and series
#
# pandas is a powerful data manipulation library in python, widely used for data analysis and data cleaning. It provides two primary data structures: Series and dataframe. A series is a one -dimensional array-like object, while a dataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes(rows and columns).

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 456.0 kB/s eta 0:00:21
#    -- ------------------------------------- 0.5/9.7 MB 456.0 kB/s eta 0:00:21
#    -- ------------------------------------- 0.5/9.7 MB 456.0 kB/s eta 0:00:21
#    --- ------------------------------------ 0.8/9.7 MB 435.1 kB/s eta 0:00:21
#    --- ------------------------------------ 0.8/9.7 MB 435.1 kB/s eta 0:00:21
#    --- ------------------------------------ 0.8/9.7 MB 435.1 kB/s eta 0:00:21
#    ---- ----------------------------------- 1.0/9.7 MB 424.6 kB/s eta 0:00:21
# ...

# %%
import pandas as pd

# %%
## series 
#3 A pandas series is a one-dimenctional array-like object that can hold any data type. It is similar a column in a table.

import pandas as pd
data =[1,2,3,4,5]
series=pd.Series(data)
print("series \n",series)
print(type(series))
# Out:
# series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.Series'>

# %%
## create a series from dictionary 

data={'a':1,'b':2, 'c':3}
series_data=pd.Series(data)
print(series_data)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data=[10,20,30]
index=['a','b','c']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
## DataFrame -> 2-dimenctional mutable and potentially heterogeneous tabular data structure with labeled axes (rows and columns). It is similar to a spreadsheet or SQL table.
## create a DatFrame from a dictionary of list

data={
    'Nmae':['Tanu','Bhanu','Sanju'],
    'Age':[21,19,23],
    'City':['Bangalore','Shimoga','Mysore']
}
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Nmae  Age       City
# 0   Tanu   21  Bangalore
# 1  Bhanu   19    Shimoga
# 2  Sanju   23     Mysore
# <class 'pandas.DataFrame'>

# %%
## Create a Dtaa Frame from a list of Dictionaries

data=[
    {'Name':'Tanu','Age':21,'City':'Bangalore'},
    {'Name':'Bhanu','Age':19,'City':'Shimoga'},
    {'Name':'Sanju','Age':23,'City':'Mysore'}

]
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age       City
# 0   Tanu   21  Bangalore
# 1  Bhanu   19    Shimoga
# 2  Sanju   23     Mysore

# %%
pd.read_csv('example.csv')
df.head(1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 pd.read_csv('example.csv')
#       2 df.head(1)
#
# File c:\Users\TANUSHREE\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
## Accessing data from DataFrame

df
# Out:
#     Nmae  Age       City
# 0   Tanu   21  Bangalore
# 1  Bhanu   19    Shimoga
# 2  Sanju   23     Mysore

# %%
df['Name']
# Out:
# 0     Tanu
# 1    Bhanu
# 2    Sanju
# Name: Name, dtype: str

# %%
## loc-> row index
df.loc[0]
# Out:
# Name         Tanu
# Age            21
# City    Bangalore
# Name: 0, dtype: object

# %%
## iloc-> column index
df.iloc[0]
# Out:
# Name         Tanu
# Age            21
# City    Bangalore
# Name: 0, dtype: object

# %%
## Accessing specified element

df.at[2,'Age']
# Out:
# np.int64(23)

# %%
df.at[2,'Name']
# Out:
# 'Sanju'

# %%
## Accessing a specified element usig iat

df.iat[2,0]
# Out:
# 'Sanju'

# %%
## Data manupulation with DataFrame
df
# Out:
#     Name  Age       City
# 0   Tanu   21  Bangalore
# 1  Bhanu   19    Shimoga
# 2  Sanju   23     Mysore

# %%
df['Salary']=[50000,60000,55000]
df
# Out:
#     Name  Age       City  Salary
# 0   Tanu   21  Bangalore   50000
# 1  Bhanu   19    Shimoga   60000
# 2  Sanju   23     Mysore   55000

# %%
## Remove a column

df.drop('Salary',axis=1,inplace=True)

# %%
df
# Out:
#     Name  Age       City
# 0   Tanu   21  Bangalore
# 1  Bhanu   19    Shimoga
# 2  Sanju   23     Mysore

# %%
#3 Add age to the column

df['Age']=df['Age']+2

# %%
df
# Out:
#     Name  Age       City
# 0   Tanu   24  Bangalore
# 1  Bhanu   22    Shimoga
# 2  Sanju   26     Mysore

# %%
df.drop(0)
# Out:
#     Name  Age     City
# 1  Bhanu   22  Shimoga
# 2  Sanju   26   Mysore

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#     Name  Age     City
# 1  Bhanu   22  Shimoga
# 2  Sanju   26   Mysore

# %%
df=pd.read_csv('sales_data.csv')
df.head()

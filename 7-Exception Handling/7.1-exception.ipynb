# %% [markdown]
# Understanding Exceptions
#
# exception handling in python allows you to handle error gracefully and take corrective action without stopping the executionof the program. Thos lesson will cover tye basics of executions, including how to usr try, except, else, and finally blocks.
#
# What are Exceptions?
#
# Exceptions are events thatdisrupt the normal flow of a program. They occur an error is encountered during program execution. common exception include:
#
# -Zero division Error: dividing by zero
# -File NotFound Error: File not found.
# -Value Error: invalid value.
# -TypeError:Invalid type

# %%
## Exception try, except block

try:
    a=b
except:
    print("the variable has not been assigned")
# Out:
# the variable has not been assigned

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    result=1/10
except ZeroDivisionError as ex:
    print(ex)
    print("please enter demoninator greater than 0")

# %%
try:
    result=1/10
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print("please enter demoninator greater than 0")
except NameError as ex1:
    print(ex1)
    print("main exception got caught here")
# Out:
# name 'b' is not defined
# main exception got caught here

# %%
try:
    num=int(input("enter a number"))
    result=1/10
except valueError:
    print("this is not a valid number")
except ZeroDivisionError:
    print("enter denominator greater than 0")
except Exception as ex:
    print(ex)

# %%
# try, except,else block
try:
    num=int(input("enter a number:"))
    result=10/num
except ValueError:
    print("this is not a valid number")
except ZeroDivisionError:
    print("you can't divide by 0")
except Exception as ex:
    print(ex)
else:
    print("the result is",result)
# Out:
# you can't divide by 0

# %%
## try, except, else, finally block

try:
    num=int(input("enter a number:"))
    result=10/num
except ValueError:
    print("this is not a valid number")
except ZeroDivisionError:
    print("you can't divide by 0")
except Exception as ex:
    print(ex)
else:
    print("the result is",result)
finally:
    print("execution complete")
# Out:
# you can't divide by 0
# execution complete

# %%
## file handling and exception handling

try:
    file=open('example1.txt','r')
    cotntent=file.read()
    a=b
    print(content)

except FileNotFoundError:
    print("the file does not exists")

except Exception as ex:
    print(ex)

finally:
    if 'file' in locals() and not file.closed():
        file.close()
        print('file close')
# Out:
# the file does not exists
